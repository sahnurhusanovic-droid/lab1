# %% [markdown]
# a=input()
# b=input()
# print(a+"***"+b)

# %%
a=input()
print(f"Hello, {a}!")

# %%
a=input()
if a.isdigit():
    print("int")
else:
    print("str")

# %%
a=int(input())
b=int(input())
print(a+b)

# %%
a=int(input())
b=int(input())
print(a/b)

# %%
a=int(input())
b=int(input())
print(a**b)

# %%
a=int(input())
b=int(input())
print(a%b)
# Out:
#  10
#  3
# 1

# %%
a=input()
b=int(input())
print(a*b)

# %%
a=input()
print(len(a))
# Out:
#  Hello
# 5

# %%
a=input()
print(a.upper())
print(a.lower())
# Out:
#  Hello
# HELLO
# hello

# %%
a=input()
print(a[0],a[-1])
# Out:
#  A
# A A

# %%
a=input()
print(a[2:5:1])
# Out:
#  abxdef
# xde

# %%
a=input()
print(a[::-1])
# Out:
#  hello
# olleh

# %%
a=input()
b=int(input())
print(f"Hello, {a}. You are {b} years old.")

# %%
a=input()
b=input()
print(b in a)
# Out:
#  hello world
#  WORLD
# False

# %%
a=input()
b=input()
print(a+b)
# Out:
#  hello world
#  hello
# hello worldhello

# %%
a=input()
b=input()
print(b,a)

# %%
a=int(input())
if a%2==0:
    print("even")
else:
    print("odd")
# Out:
#  1
# odd

# %%
a=input()
b=input()
c=input()
print(a.replace(b,c))
# Out:
#  Hello world
#  world
#  there
# Hello there

# %%
a=int(input())
b=int(input())
if a>b:
    print(a)
elif a<b:
    print(b)
else:
    print("equal")
